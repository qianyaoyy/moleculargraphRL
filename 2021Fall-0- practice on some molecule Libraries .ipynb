# %%
pip install qml
# Out:
# ...
#      |████████████████████████████████| 41 kB 450 kB/s
# ...
#   Created wheel for qml: filename=qml-0.4.0.27-cp37-cp37m-linux_x86_64.whl size=1049673 sha256=df75cfebea170ae29ced5b3a67c5d823fd4ee02c2319a971a5816e77a9ab7f3c
#   Stored in directory: /root/.cache/pip/wheels/e4/6f/cc/cc6ed17565977d62aab6730e348c2e9d8c51c559896c467f74
# Successfully built qml
# ...

# %%
pip install rdkit-pypi
# Out:
# ...
#      |████████████████████████████████| 19.7 MB 7.1 MB/s
# ...
